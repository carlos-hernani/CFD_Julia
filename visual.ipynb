# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "./05_Inviscid_Burgers_WENO/" + "solution_" + "d" + ".txt"
df = pd.read_csv(path, sep=" ", header=None).drop(columns=11)
df
# Out:
#         0         1         2         3         4         5         6   \
# 0    0.000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.005  0.027148  0.023904  0.021352  0.019293  0.017595  0.016173
# 2    0.010  0.054279  0.047798  0.042698  0.038581  0.035188  0.032343
# 3    0.015  0.081375  0.071670  0.064030  0.057861  0.052774  0.048510
# 4    0.020  0.108420  0.095512  0.085343  0.077127  0.070352  0.064669
# ..     ...       ...       ...       ...       ...       ...       ...
# 196  0.980 -0.108420 -0.095512 -0.085343 -0.077127 -0.070352 -0.064669
# 197  0.985 -0.081375 -0.071670 -0.064030 -0.057861 -0.052774 -0.048510
# 198  0.990 -0.054279 -0.047798 -0.042698 -0.038581 -0.035188 -0.032343
# 199  0.995 -0.027148 -0.023904 -0.021352 -0.019293 -0.017595 -0.016173
# 200  1.000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            7         8         9         10
# 0    0.000000  0.000000  0.000000  0.000000
# ...

# %%
# columns are time from 0.025 to 0.25 in 0.025 intervals

# %%
path = "./05_Inviscid_Burgers_WENO/" + "solution_" + "d" + ".csv"
df = pd.read_csv(path, header=None).drop(columns=df.columns[-1], axis=1)
df
# Out:
#          0         1         2         3         4         5         6    \
# 0     0.0000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.0005  0.003093  0.003046  0.003000  0.002956  0.002913  0.002871
# 2     0.0010  0.006186  0.006092  0.006000  0.005912  0.005826  0.005742
# 3     0.0015  0.009279  0.009138  0.009001  0.008868  0.008738  0.008613
# 4     0.0020  0.012372  0.012183  0.012001  0.011823  0.011651  0.011484
# ...      ...       ...       ...       ...       ...       ...       ...
# 1996  0.9980 -0.012372 -0.012183 -0.012001 -0.011823 -0.011651 -0.011484
# 1997  0.9985 -0.009279 -0.009138 -0.009001 -0.008868 -0.008738 -0.008613
# 1998  0.9990 -0.006186 -0.006092 -0.006000 -0.005912 -0.005826 -0.005742
# 1999  0.9995 -0.003093 -0.003046 -0.003000 -0.002956 -0.002913 -0.002871
# 2000  1.0000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            7         8         9    ...       91        92        93   \
# ...

# %%
plt.plot(df.iloc[:,0], df.iloc[:, 100])

# %%
df.plot(x=df.iloc[:,0], y = df.iloc[:, 1:10:100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/idal/Documents/CFD_Julia/visual.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/idal/Documents/CFD_Julia/visual.ipynb#ch0000004?line=0'>1</a> df.plot(x=df.iloc[:,0], y = df.iloc[:, 1:10:100])
#
# File ~/Documents/CFD_Julia/.venv10/lib/python3.10/site-packages/pandas/plotting/_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     <a href='file:///~/Documents/CFD_Julia/.venv10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=934'>935</a> if is_integer(x) and not data.columns.holds_integer():
#     <a href='file:///~/Documents/CFD_Julia/.venv10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=935'>936</a>     x = data_cols[x]
# ...
